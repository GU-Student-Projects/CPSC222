# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset_weather_alexandria = pd.read_csv('alexandria.csv', header=0)

dataset_weather_alexandria.shape

dataset_weather_alexandria.describe()
# Out:
#           tempmax     tempmin        temp  feelslikemax  feelslikemin  \
# count  180.000000  180.000000  180.000000    180.000000    180.000000
# mean    29.370556   17.821111   23.561667     29.487778     17.766111
# std      4.122573    4.219203    3.489414      4.668241      4.355760
# min     13.800000    6.300000   11.300000     13.800000      3.800000
# 25%     27.375000   14.800000   21.675000     26.800000     14.800000
# 50%     29.850000   17.300000   24.050000     29.250000     17.300000
# 75%     32.025000   21.525000   26.225000     32.600000     21.525000
# max     39.300000   25.800000   29.900000     42.000000     25.800000
#
#         feelslike         dew    humidity      precip  precipprob  ...  \
# count  180.000000  180.000000  180.000000  180.000000  180.000000  ...
# mean    23.646111   12.457222   54.898889    1.786583   32.222222  ...
# std      3.845092    6.659978   17.329598    4.402338   46.863114  ...
# ...

# %%
smaller_df = dataset_weather_alexandria[['temp','humidity']]
smaller_df.plot()
plt.show()
