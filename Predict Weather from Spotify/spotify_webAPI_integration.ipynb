# %%
import pandas as pd

playlist_data = pd.read_csv('./cleaned_data/spotify_data/playlistCSV.csv', header=0)
streaming_history = pd.read_csv('./cleaned_data/spotify_data/streamingHistoryCSV.csv', header=0)

# %%
merged_dataset = streaming_history.merge(playlist_data, on='trackName',)
merged_dataset['time'] = merged_dataset['time'].str.split(' ').str[1]
merged_dataset['track_id'] = merged_dataset['trackUri'].str.split('track:').str[1]

# %%
def month_to_int(value):
    if value == 'June':
        return 6
    elif value == 'July':
        return 7
    elif value == 'August':
        return 8
    else:
        return 9

# %%
merged_dataset['Month'] = merged_dataset['Month'].apply(month_to_int)

# %%
merged_dataset['date'] = merged_dataset['Month'].astype(str) + '/' + merged_dataset['Day'].astype(str) + '/' + merged_dataset['Year'].astype(str)
merged_dataset['hour'] = merged_dataset['time'].str.split(':').str[0]

# %%
merged_dataset = merged_dataset.drop_duplicates(subset='time')
merged_dataset.head()
# Out:
#                                    artistName_x  Year  Month  Day      time  \
# 0                           "Weird Al" Yankovic  2023      6   22  02:00:00
# 1                           "Weird Al" Yankovic  2023      7   29  02:38:00
# 2                           "Weird Al" Yankovic  2023      7   29  01:10:00
# 3  ...And You Will Know Us by the Trail of Dead  2023      7   23  01:33:00
# 5  ...And You Will Know Us by the Trail of Dead  2023      8   21  03:10:00
#
#    Sum of msPlayed                                          trackName  \
# 0           202920  Amish Paradise (Parody of "Gangsta's Paradise"...
# 1           202920  Amish Paradise (Parody of "Gangsta's Paradise"...
# 2           328773  The Saga Begins (Lyrical Adaption of "American...
# 3           325600                               Wasted State Of Mind
# 5            25550                               Wasted State Of Mind
#
#                albumName                                  artistName_y  \
# 0           Bad Hair Day                           "Weird Al" Yankovic
# 1           Bad Hair Day                           "Weird Al" Yankovic
# 2  Running With Scissors                           "Weird Al" Yankovic
# 3             So Divided  ...And You Will Know Us by the Trail of Dead
# 5             So Divided  ...And You Will Know Us by the Trail of Dead
#
#                                trackUri    playlists.name  \
# 0  spotify:track:5r96TaQquRrlo3Ym3ZlSL2  HOmeWorK BANgers
# 1  spotify:track:5r96TaQquRrlo3Ym3ZlSL2  HOmeWorK BANgers
# 2  spotify:track:74sUbOF9Zm8LdGUJjxleTl  HOmeWorK BANgers
# 3  spotify:track:16XbElFPv3A7TrzRJntVYd       Missing Her
# 5  spotify:track:16XbElFPv3A7TrzRJntVYd       Missing Her
#
#                  track_id       date hour
# 0  5r96TaQquRrlo3Ym3ZlSL2  6/22/2023   02
# 1  5r96TaQquRrlo3Ym3ZlSL2  7/29/2023   02
# 2  74sUbOF9Zm8LdGUJjxleTl  7/29/2023   01
# 3  16XbElFPv3A7TrzRJntVYd  7/23/2023   01
# 5  16XbElFPv3A7TrzRJntVYd  8/21/2023   03

# %%
unique_songs = merged_dataset['trackUri'].unique()
unique_songs = pd.DataFrame(unique_songs)
unique_songs.columns = ['trackUri']
display(unique_songs)
# Out:
#                                  trackUri
# 0    spotify:track:5r96TaQquRrlo3Ym3ZlSL2
# 1    spotify:track:74sUbOF9Zm8LdGUJjxleTl
# 2    spotify:track:16XbElFPv3A7TrzRJntVYd
# 3    spotify:track:2SkJKMfjpYsNv0KWOxiegX
# 4    spotify:track:7dnQZxpbKsHNmtlWcRdsR4
# ..                                    ...
# 250  spotify:track:7CskFQLRb7IdIEdnAnjMDV
# 251  spotify:track:7LygtNjQ65PSdzVjUnHXQb
# 252  spotify:track:6TSDRzJGwbK9cajVbtqlPV
# 253  spotify:track:3CkjLJYnnyOtGk4Jx4iYS4
# 254  spotify:track:6L3VWDPDTQkQFkqvmpAUMU
#
# [255 rows x 1 columns]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from apikey import *

client_id = CLIENT_KEY
client_secret = SECRET_KEY
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
import time
from tqdm import tqdm

def track_info_progress_bar(unique_songs,api_dataset):
    requests_per_hour = 500
    
    requests_made_hour = 0
    start_time = time.time()
    
    

    for track_uri in tqdm(enumerate(unique_songs['trackUri']), total=len(unique_songs)):
        audio_features = sp.audio_features(track_uri[1])
        new_row = pd.DataFrame(audio_features)
        api_dataset = pd.concat([api_dataset,new_row], ignore_index=True)
        
        requests_made_hour += 1
        elapsed_time = time.time() - start_time
        #time.sleep(60*3)
       
        if requests_made_hour >= requests_per_hour and elapsed_time < 3600:
            time_to_sleep = 3600 - elapsed_time
            time.sleep(time_to_sleep)
            requests_made_hour = 0
            start_time = time.time()

        #tqdm.write(f"Processed: {index + 1}/{end_value}")
    return api_dataset

# %%
api_dataset = pd.DataFrame()
api_dataset = track_info_progress_bar(unique_songs,api_dataset)
display(api_dataset)
# Out:
# 100%|██████████| 255/255 [00:21<00:00, 11.89it/s]
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.728   0.448    8   -10.540     1       0.1720      0.103000
# 1           0.487   0.429    4    -8.716     0       0.0391      0.332000
# 2           0.462   0.806    3    -3.283     1       0.0341      0.260000
# 3           0.709   0.913    7    -5.148     1       0.0748      0.018200
# 4           0.396   0.635    4    -5.665     0       0.0394      0.387000
# ..            ...     ...  ...       ...   ...          ...           ...
# 250         0.391   0.828    7    -4.156     1       0.0722      0.000708
# 251         0.472   0.946    2    -4.591     1       0.1450      0.037200
# 252         0.714   0.721    9    -5.049     1       0.0783      0.273000
# 253         0.219   0.952    2    -3.621     1       0.1760      0.000051
# 254         0.623   0.886    1    -3.044     1       0.0404      0.024500
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0              0.0000    0.2670    0.483   80.902  audio_features
# 1              0.0000    0.2070    0.508  143.582  audio_features
# 2              0.0000    0.1140    0.354  165.925  audio_features
# 3              0.0000    0.1670    0.519  108.024  audio_features
# 4              0.0000    0.2710    0.306  126.981  audio_features
# ..                ...       ...      ...      ...             ...
# 250            0.0000    0.0781    0.561  177.910  audio_features
# 251            0.0000    0.3520    0.486  177.489  audio_features
# 252            0.2450    0.1740    0.415   83.021  audio_features
# 253            0.0989    0.1570    0.172  112.886  audio_features
# 254            0.0000    0.2470    0.709   92.021  audio_features
#
#                          id                                   uri  \
# 0    5r96TaQquRrlo3Ym3ZlSL2  spotify:track:5r96TaQquRrlo3Ym3ZlSL2
# 1    74sUbOF9Zm8LdGUJjxleTl  spotify:track:74sUbOF9Zm8LdGUJjxleTl
# 2    16XbElFPv3A7TrzRJntVYd  spotify:track:16XbElFPv3A7TrzRJntVYd
# 3    2SkJKMfjpYsNv0KWOxiegX  spotify:track:2SkJKMfjpYsNv0KWOxiegX
# 4    7dnQZxpbKsHNmtlWcRdsR4  spotify:track:7dnQZxpbKsHNmtlWcRdsR4
# ..                      ...                                   ...
# 250  7CskFQLRb7IdIEdnAnjMDV  spotify:track:7CskFQLRb7IdIEdnAnjMDV
# 251  7LygtNjQ65PSdzVjUnHXQb  spotify:track:7LygtNjQ65PSdzVjUnHXQb
# 252  6TSDRzJGwbK9cajVbtqlPV  spotify:track:6TSDRzJGwbK9cajVbtqlPV
# 253  3CkjLJYnnyOtGk4Jx4iYS4  spotify:track:3CkjLJYnnyOtGk4Jx4iYS4
# 254  6L3VWDPDTQkQFkqvmpAUMU  spotify:track:6L3VWDPDTQkQFkqvmpAUMU
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5r96TaQquRrl...
# 1    https://api.spotify.com/v1/tracks/74sUbOF9Zm8L...
# 2    https://api.spotify.com/v1/tracks/16XbElFPv3A7...
# 3    https://api.spotify.com/v1/tracks/2SkJKMfjpYsN...
# 4    https://api.spotify.com/v1/tracks/7dnQZxpbKsHN...
# ..                                                 ...
# 250  https://api.spotify.com/v1/tracks/7CskFQLRb7Id...
# 251  https://api.spotify.com/v1/tracks/7LygtNjQ65PS...
# 252  https://api.spotify.com/v1/tracks/6TSDRzJGwbK9...
# 253  https://api.spotify.com/v1/tracks/3CkjLJYnnyOt...
# 254  https://api.spotify.com/v1/tracks/6L3VWDPDTQkQ...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/5r96...       202920
# 1    https://api.spotify.com/v1/audio-analysis/74sU...       328773
# 2    https://api.spotify.com/v1/audio-analysis/16Xb...       325600
# 3    https://api.spotify.com/v1/audio-analysis/2SkJ...       229320
# 4    https://api.spotify.com/v1/audio-analysis/7dnQ...       178787
# ..                                                 ...          ...
# 250  https://api.spotify.com/v1/audio-analysis/7Csk...       217159
# 251  https://api.spotify.com/v1/audio-analysis/7Lyg...       201027
# 252  https://api.spotify.com/v1/audio-analysis/6TSD...       164093
# 253  https://api.spotify.com/v1/audio-analysis/3Ckj...       176307
# 254  https://api.spotify.com/v1/audio-analysis/6L3V...       228467
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 250               4
# 251               4
# 252               4
# 253               1
# 254               4
#
# [255 rows x 18 columns]

# %%
api_dataset.to_csv('./cleaned_data/mergedSpotifyData.csv', index=False)

# %%
columns_to_drop = ['analysis_url','track_href','type','uri']
api_dataset.drop(columns_to_drop, axis=1,inplace=True)
api_dataset.rename(columns={'id': 'track_id'}, inplace=True)

# %%
spotify_dataset = merged_dataset.merge(api_dataset, on='track_id')
columns_to_drop = ['trackUri','Sum of msPlayed','artistName_x']
spotify_dataset.drop(columns_to_drop, axis=1,inplace=True)
spotify_dataset.rename(columns={'artistName_y': 'artistName'}, inplace=True)
spotify_dataset.to_csv('apiData.csv', index=False)
display(spotify_dataset)
# Out:
#       Year  Month  Day      time  \
# 0     2023      6   22  02:00:00
# 1     2023      7   29  02:38:00
# 2     2023      7   29  01:10:00
# 3     2023      7   23  01:33:00
# 4     2023      8   21  03:10:00
# ...    ...    ...  ...       ...
# 1296  2023      6    8  11:32:00
# 1297  2023      8   30  15:43:00
# 1298  2023      7   23  08:29:00
# 1299  2023      8   12  18:04:00
# 1300  2023      6   16  16:40:00
#
#                                               trackName  \
# 0     Amish Paradise (Parody of "Gangsta's Paradise"...
# 1     Amish Paradise (Parody of "Gangsta's Paradise"...
# 2     The Saga Begins (Lyrical Adaption of "American...
# 3                                  Wasted State Of Mind
# 4                                  Wasted State Of Mind
# ...                                                 ...
# 1296                                     Heart and Soul
# 1297                                         Cherry Pie
# 1298                                           Que Sera
# 1299                                              Woman
# 1300                            Something to Believe In
#
#                             albumName  \
# 0                        Bad Hair Day
# 1                        Bad Hair Day
# 2               Running With Scissors
# 3                          So Divided
# 4                          So Divided
# ...                               ...
# 1296    Great Divide (Deluxe Version)
# 1297                       Cherry Pie
# 1298  Tales of the Forgotten Melodies
# 1299                       Wolfmother
# 1300              Home of the Strange
#
#                                         artistName       playlists.name  \
# 0                              "Weird Al" Yankovic     HOmeWorK BANgers
# 1                              "Weird Al" Yankovic     HOmeWorK BANgers
# 2                              "Weird Al" Yankovic     HOmeWorK BANgers
# 3     ...And You Will Know Us by the Trail of Dead          Missing Her
# 4     ...And You Will Know Us by the Trail of Dead          Missing Her
# ...                                            ...                  ...
# 1296                                 Twin Atlantic          Missing Her
# 1297                                       Warrant  Rock Paper Scissors
# 1298                                    Wax Tailor          Missing Her
# 1299                                    Wolfmother  Rock Paper Scissors
# 1300                               Young the Giant             The Knew
#
#                     track_id       date  ... loudness  mode  speechiness  \
# 0     5r96TaQquRrlo3Ym3ZlSL2  6/22/2023  ...  -10.540     1       0.1720
# 1     5r96TaQquRrlo3Ym3ZlSL2  7/29/2023  ...  -10.540     1       0.1720
# 2     74sUbOF9Zm8LdGUJjxleTl  7/29/2023  ...   -8.716     0       0.0391
# 3     16XbElFPv3A7TrzRJntVYd  7/23/2023  ...   -3.283     1       0.0341
# 4     16XbElFPv3A7TrzRJntVYd  8/21/2023  ...   -3.283     1       0.0341
# ...                      ...        ...  ...      ...   ...          ...
# 1296  7CskFQLRb7IdIEdnAnjMDV   6/8/2023  ...   -4.156     1       0.0722
# 1297  7LygtNjQ65PSdzVjUnHXQb  8/30/2023  ...   -4.591     1       0.1450
# 1298  6TSDRzJGwbK9cajVbtqlPV  7/23/2023  ...   -5.049     1       0.0783
# 1299  3CkjLJYnnyOtGk4Jx4iYS4  8/12/2023  ...   -3.621     1       0.1760
# 1300  6L3VWDPDTQkQFkqvmpAUMU  6/16/2023  ...   -3.044     1       0.0404
#
#       acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.103000            0.0000    0.2670    0.483   80.902       202920
# 1         0.103000            0.0000    0.2670    0.483   80.902       202920
# 2         0.332000            0.0000    0.2070    0.508  143.582       328773
# 3         0.260000            0.0000    0.1140    0.354  165.925       325600
# 4         0.260000            0.0000    0.1140    0.354  165.925       325600
# ...            ...               ...       ...      ...      ...          ...
# 1296      0.000708            0.0000    0.0781    0.561  177.910       217159
# 1297      0.037200            0.0000    0.3520    0.486  177.489       201027
# 1298      0.273000            0.2450    0.1740    0.415   83.021       164093
# 1299      0.000051            0.0989    0.1570    0.172  112.886       176307
# 1300      0.024500            0.0000    0.2470    0.709   92.021       228467
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1296               4
# 1297               4
# 1298               4
# 1299               1
# 1300               4
#
# [1301 rows x 24 columns]
